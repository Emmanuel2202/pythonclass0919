# %%
class patientmanagementsystem:
    def __init__(self,Name,Gender,dob,hosiptalnumber):
        self.Name =Name
        self.Gender =Gender
        self.dob=dob
        self.hosiptalnumber =hosiptalnumber
    def accept(self,NAME,GENDER,DOB,HOSPITALNUMBER):
        ob = patientmanagementsystem(NAME,GENDER,DOB,HOSPITALNUMBER)
        plist.append(ob)
    def display(self,ob):
        print(f'''NAME:{ob.Name}
GENDER:{ob.Gender}
DATE OF BIRTH:{ob.dob}
HOSPITAL NUMBER:{ob.hosiptalnumber}
''')
    def search(self):
        sn = int(input('Enter hospital number to find:'))
        for i in range(len(plist)):
            if plist[i].hosiptalnumber == sn:
                return i
            
    def update(self):
        oldnumber =int(input('Enter hospital number to update:'))
        newnumber = int(input('Enter New hospital number:'))
        s = obj.search()
        plist[s].hosiptalnumber = newnumber
    def delete(self):
        oldnumber =int(input('Enter hospital number to delete:'))
        i  = obj.search()
        del plist[i]
plist = []
obj = patientmanagementsystem('','','',0)
print("OPERATION USED.")
print('''ACCEPT PATIENT
DISPLAY PATIENT 
SEARCH DETAILS OF A PATIENT
UPDATE DETAILS OF A PATIENT
DELETE DETAILS OF A PATIENT
''')
x= input('Enter y as yes and n as no to performe your operation')
n=1
while x == 'y':
    choice = int(input('ENTER CHOICE:'))
    if choice == 1:
        obj.accept(input('NAME'),input('GENDER'),input('DOB'),int(input('HOSPITAL NUMBER')))
    elif choice ==2:
        print('LIST OF PATIENT')
        for i in range(len(plist)):
            obj.display(plist[i])
    elif choice==3:
        s = obj.search()
        obj.display(plist[s])
    elif choice == 4:
        obj.update()
        for i in range(len(plist)):
            obj.display(plist[i])
           
    elif choice ==5:
        obj.delete()
        print('LIST AFTER DELETION')
        for i in range(len(plist)):
            obj.display(plist[i])
    else:
        print('INVALID OPTION TRY AGAIN')
    x= input('Enter y as yes and n as no to performe your operation')
    n=n+1
